# %%
from GQLib.Framework import Framework
from GQLib.Optimizers import MPGA, PSO, SA, SGA
from GQLib.Models import LPPL, LPPLS
from datetime import datetime

# %% [markdown]
# # DAILY

# %% [markdown]
# ## Run full process for all Optimizers and all dates

# %%
freq = "daily"
model = LPPL

fw = Framework(freq, model)
optimizers = [PSO, SA, SGA, MPGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running process for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running process for {set_name} from {start_date} to {end_date}")
        fw.process(start_date, end_date, optimizer)
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/{optimizer.__name__}/{model.__name__}-results_{freq}_{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"
        # Sauvegarder les résultats
        fw.save_results(fw.results, filename)
        # On check la sig   nificativité des résultats
        fw.analyze()
        # On peut visualiser les résultats finaux
        fw.visualize()
# Out:
# Running process for PSO
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [01:35<00:00,  1.06s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.84result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [01:22<00:00,  1.09subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.30result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [01:27<00:00,  1.03subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.23result/s]
# Running process for SA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:04<00:00, 20.50subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.94result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:03<00:00, 25.03subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 27.36result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:03<00:00, 24.02subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.33result/s]
# Running process for SGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:21<00:00,  4.22subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 26.43result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:18<00:00,  4.77subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.13result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:21<00:00,  4.20subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.14result/s]
# Running process for MPGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [04:45<00:00,  3.17s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 27.81result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [03:40<00:00,  2.45s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.99result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [04:39<00:00,  3.11s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.11result/s]

# %%
freq = "daily"
model = LPPLS

fw = Framework(freq, model)
optimizers = [PSO, SA, SGA, MPGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running process for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running process for {set_name} from {start_date} to {end_date}")
        fw.process(start_date, end_date, optimizer)
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/{optimizer.__name__}/{model.__name__}-results_{freq}_{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"
        # Sauvegarder les résultats
        fw.save_results(fw.results, filename)
        # On check la sig   nificativité des résultats
        fw.analyze()
        # On peut visualiser les résultats finaux
        fw.visualize()
# Out:
# Running process for PSO
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [01:58<00:00,  1.31s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 26.75result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [01:44<00:00,  1.17s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.64result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [01:50<00:00,  1.22s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 27.36result/s]
# Running process for SA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:05<00:00, 16.56subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.05result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:04<00:00, 20.58subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 27.58result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:04<00:00, 19.79subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.00result/s]
# Running process for SGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:30<00:00,  2.99subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 22.58result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:23<00:00,  3.79subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.55result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:26<00:00,  3.36subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.60result/s]
# Running process for MPGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [05:48<00:00,  3.87s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.61result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [05:28<00:00,  3.65s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 27.14result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [05:11<00:00,  3.47s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.65result/s]

# %% [markdown]
# ## Run analysis for all Optimizers and all dates

# %%
freq = "daily"

fw = Framework(freq)
optimizers = [MPGA, PSO, SA, SGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running analysis for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running analysis for {set_name} from {start_date} to {end_date}")
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/{optimizer.__name__}/results_{freq}_{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"

        # On check la sig   nificativité des résultats
        fw.analyze(filename, show=True)
        # On peut visualiser les résultats finaux
        fw.visualize()

# %% [markdown]
# # WEEKLY

# %% [markdown]
# ## Run full process for all Optimizers and all dates

# %%
freq = "weekly"

fw = Framework(freq)
optimizers = [MPGA, PSO, SA, SGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running process for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running process for {set_name} from {start_date} to {end_date}")
        fw.process(start_date, end_date, optimizer)
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/{optimizer.__name__}/results_{freq}_{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"
        # Sauvegarder les résultats
        fw.save_results(fw.results, filename)
        # On check la sig   nificativité des résultats
        fw.analyze()
        # On peut visualiser les résultats finaux
        fw.visualize()

# %% [markdown]
# ## Run analysis for all Optimizers and all dates

# %%
freq = "weekly"

fw = Framework(freq)
optimizers = [MPGA, PSO, SA, SGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running analysis for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running analysis for {set_name} from {start_date} to {end_date}")
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/{optimizer.__name__}/results_{freq}_{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"

        # On check la sig   nificativité des résultats
        fw.analyze(filename, show=True)
        # On peut visualiser les résultats finaux
        fw.visualize()
