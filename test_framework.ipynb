# %%
from GQLib.Framework import Framework
from GQLib.Optimizers import MPGA, PSO, SA, SGA
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# %% [markdown]
# # RUN ALL

# %%
from GQLib.Framework import Framework
fw = Framework("daily")
fw.generate_all_dates(optimizers=[SA(), SGA(), PSO(), MPGA()], nb_tc=10, significativity_tc=0.3, save=False)
# Out:
# FREQUENCY : daily
# Running process for SA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:234: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   params = np.linalg.inv(V.T @ V) @ (V.T @ y)
# Processing subintervals: 100%|██████████| 90/90 [00:42<00:00,  2.13subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:32<00:00,  2.74result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:25<00:00,  3.52subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:15<00:00,  5.87result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:20<00:00,  4.49subinterval/s]
# Analyzing results:  36%|███▌      | 32/90 [00:11<00:20,  2.78result/s]

# %% [markdown]
# ## Weekly

# %%
from GQLib.Framework import Framework
fw = Framework("weekly")
fw.generate_all_dates(nb_tc=10)
# Out:
# FREQUENCY : weekly
# Running process for PSO
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 18/18 [00:17<00:00,  1.00subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 14.39result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 18/18 [00:17<00:00,  1.02subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 13.66result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 18/18 [00:16<00:00,  1.06subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 14.83result/s]
# Running process for MPGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 18/18 [00:41<00:00,  2.29s/subinterval]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 14.40result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 18/18 [00:45<00:00,  2.52s/subinterval]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 15.26result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 18/18 [00:47<00:00,  2.63s/subinterval]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 11.94result/s]
# Running process for SA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 18/18 [00:01<00:00, 11.59subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 13.28result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 18/18 [00:01<00:00, 13.32subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 14.54result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 18/18 [00:01<00:00, 13.42subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 12.60result/s]
# Running process for SGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 18/18 [00:03<00:00,  5.56subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 13.80result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 18/18 [00:02<00:00,  6.73subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 13.62result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 18/18 [00:03<00:00,  5.43subinterval/s]
# Analyzing results: 100%|██████████| 18/18 [00:01<00:00, 11.48result/s]

# %% [markdown]
# # PSO

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = PSO()
results = fw.process("04/01/2003", "04/02/2008", optimizer= optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(results, "results/results-2003_2008_try_PSO.json")
# On check la significativité des résultats
best_results = fw.analyze(results)
# On peut visualiser les résultats finaux
fw.visualize(best_results)
# Out:
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:234: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   params = np.linalg.inv(V.T @ V) @ (V.T @ y)
# Processing subintervals: 100%|██████████| 90/90 [04:43<00:00,  3.15s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:18<00:00,  4.97result/s]

# %% [markdown]
# ### Run for all Dates PSO

# %% [markdown]
# # MGPA

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = MPGA()
fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(results, "results/results-2003_2008_try_MPGA.json")
# On check la significativité des résultats
fw.analyze()
# On peut visualiser les résultats finaux
fw.visualize()
# Out:
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 # On renseigne les dates du sample et l'optimiseur à utiliser
#       3 optimizer = MPGA()
# ----> 4 fw.process("04/01/2003", "04/02/2008", optimizer)
#       5 # On peut save en json nos résultats pour les réutiliser plus tard
#       6 fw.save_results(results, "results/results-2003_2008_try_MPGA.json")
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Framework.py:119, in Framework.process(self, time_start, time_end, optimizer)
#     116 # Optimize parameters for each subinterval
#     117 for (sub_start, sub_end, sub_data) in tqdm(subintervals, desc="Processing subintervals", unit="subinterval"):
# --> 119     bestObjV, bestParams = optimizer.fit(sub_start, sub_end, sub_data)
#     120     results.append({
#     121         "sub_start": sub_start,
#     122         "sub_end": sub_end,
#     123         "bestObjV": bestObjV,
#     124         "bestParams": bestParams.tolist()
#     125     })
#     126 return results
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Optimizers\MPGA.py:85, in MPGA.fit(self, start, end, data)
#      83         bestObjV = local_min
#      84         bestChrom = populations[m][np.argmin(fit)]
# ---> 85 self.fitness_history[m].append(bestObjV)
#      87 # Initialize loop counters
#      88 gen = 1
#
# IndexError: list index out of range

# %% [markdown]
# ### Run all MGPA

# %% [markdown]
# # SA

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = SA()
results = fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(results, "results/SA/daily/results-2003_2008_try_SA.json")
# On check la significativité des résultats
best_results = fw.analyze(results)
# On peut visualiser les résultats finaux
fw.visualize(best_results)
# Out:
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:234: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   params = np.linalg.inv(V.T @ V) @ (V.T @ y)
# Processing subintervals: 100%|██████████| 90/90 [00:31<00:00,  2.81subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:21<00:00,  4.21result/s]

# %% [markdown]
# ## SGA

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = SGA()
results = fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(results, "results/SGA/daily/results-2003_2008_try_SGA.json")
# On check la significativité des résultats
best_results = fw.analyze(results)
# On peut visualiser les résultats finaux
fw.visualize(best_results)
# Out:
# Processing subintervals: 100%|██████████| 90/90 [01:28<00:00,  1.02subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:23<00:00,  3.85result/s]

# %% [markdown]
# # Run ALL

# %%
# Out:
# FREQUENCY : daily
# Running process for PSO
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:234: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   params = np.linalg.inv(V.T @ V) @ (V.T @ y)
# Processing subintervals: 100%|██████████| 90/90 [04:52<00:00,  3.25s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.49result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [03:37<00:00,  2.42s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.42result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [04:23<00:00,  2.92s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:18<00:00,  4.88result/s]
# Running process for MPGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [16:11<00:00, 10.79s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.31result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [11:32<00:00,  7.69s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:15<00:00,  5.92result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [12:36<00:00,  8.40s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:14<00:00,  6.15result/s]
# Running process for SA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:13<00:00,  6.56subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:15<00:00,  5.67result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals:  41%|████      | 37/90 [00:04<00:06,  8.83subinterval/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from GQLib.Framework import Framework
#       2 fw = Framework("daily")
# ----> 3 fw.generate_all_dates()
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Framework.py:339, in Framework.generate_all_dates(self, optimizers)
#     337 print(f"Running process for {set_name} from {start_date} to {end_date}")
#     338 # Exécute le processus d'optimisation pour l'intervalle de dates donné
# --> 339 results = self.process(start_date, end_date, optimizer)
#     340 # Conversion des chaînes de dates en objets datetime pour faciliter le formatage
#     341 start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Framework.py:124, in Framework.process(self, time_start, time_end, optimizer)
#     117 for (sub_start, sub_end, sub_data) in tqdm(subintervals, desc="Processing subintervals", unit="subinterval"):
#     119     bestObjV, bestParams = optimizer.fit(sub_start, sub_end, sub_data)
#     120     results.append({
#     121         "sub_start": sub_start,
#     122         "sub_end": sub_end,
#     123         "bestObjV": bestObjV,
# --> 124         "bestParams": bestParams.tolist()
#     125     })
#     126 return results
#
# AttributeError: 'list' object has no attribute 'tolist'
