# %%
from GQLib.Framework import Framework
from GQLib.Optimizers import MPGA, PSO, SA, SGA
from datetime import datetime

# %% [markdown]
# # PSO

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = PSO()
results = fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(results, "results/results-2003_2008_try_PSO.json")
# On check la significativité des résultats
fw.analyze()
# On peut visualiser les résultats finaux
fw.visualize()
# Out:
# Processing subintervals:   0%|          | 0/90 [00:02<?, ?subinterval/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 # On renseigne les dates du sample et l'optimiseur à utiliser
#       3 optimizer = PSO('daily')
# ----> 4 fw.process("04/01/2003", "04/02/2008", optimizer)
#       5 # On peut save en json nos résultats pour les réutiliser plus tard
#       6 fw.save_results(fw.results, "results/results-2003_2008_try_PSO.json")
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Framework.py:126, in Framework.process(self, time_start, time_end, optimizer)
#     123 # Optimize parameters for each subinterval
#     124 for (sub_start, sub_end, sub_data) in tqdm(self.subintervals, desc="Processing subintervals", unit="subinterval"):
#     125     # optimizer = optimizer_class(self.frequency)
# --> 126     bestObjV, bestParams = optimizer.fit(sub_start, sub_end, sub_data)
#     127     self.results.append({
#     128         "sub_start": sub_start,
#     129         "sub_end": sub_end,
#     130         "bestObjV": bestObjV,
#     131         "bestParams": bestParams.tolist()
#     132     })
#     133 return self.results
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Optimizers\PSO.py:110, in PSO.fit(self, start, end, data)
#     106 while current <= self.MAX_GEN:
#     107
#     108     # Update each particle position in the swarm
#     109     for m in range(self.NUM_PARTICLES):
# --> 110         particles[m].update_position(global_best_solution, data)
#     112     # Update the new global best particle
#     113     best_particle : Particle = min(particles, key=lambda p: p.local_best_fitness)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Run for all Dates PSO

# %%
fw = Framework("daily")
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}
# Optimiseur à utiliser (PSO)
optimizer = PSO()  # Remplacez par le nom réel de l'optimiseur
# Boucle pour exécuter le processus pour chaque set de dates
for set_name, (start_date, end_date) in dates_sets.items():
    print(f"Running process for {set_name} from {start_date} to {end_date}")
    fw.process(start_date, end_date, optimizer)
    # On peut save en json nos résultats pour les réutiliser plus tard
    start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
    end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
    filename = f"results/PSO/results-{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_PSO.json"
    # Sauvegarder les résultats
    fw.save_results(fw.results, filename)
    # On check la sig   nificativité des résultats
    fw.analyze()
    # On peut visualiser les résultats finaux
    fw.visualize()
# Out:
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:230: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   params = np.linalg.inv(V.T @ V) @ (V.T @ y)
# Processing subintervals: 100%|██████████| 90/90 [04:41<00:00,  3.13s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:17<00:00,  5.28result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [03:54<00:00,  2.61s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.29result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [04:33<00:00,  3.04s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:18<00:00,  4.93result/s]

# %% [markdown]
# # MGPA

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = MPGA()
fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(fw.results, "results/results-2003_2008_try_MPGA.json")
# On check la significativité des résultats
fw.analyze()
# On peut visualiser les résultats finaux
fw.visualize()
# Out:
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:258: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   fitness[i] = njit_RSS(population[i], data)
# Processing subintervals: 100%|██████████| 90/90 [13:22<00:00,  8.91s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.48result/s]

# %% [markdown]
# ### Run all MGPA

# %%
fw = Framework("daily")
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

# Optimiseur à utiliser (PSO)
optimizer = MPGA()  # Remplacez par le nom réel de l'optimiseur

# Boucle pour exécuter le processus pour chaque set de dates
for set_name, (start_date, end_date) in dates_sets.items():
    print(f"Running process for {set_name} from {start_date} to {end_date}")
    fw.process(start_date, end_date, optimizer)
    # On peut save en json nos résultats pour les réutiliser plus tard
    start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
    end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
    filename = f"results/MPGA/results-{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_PSO.json"
    # Sauvegarder les résultats
    fw.save_results(fw.results, filename)
    # On check la sig   nificativité des résultats
    fw.analyze()
    # On peut visualiser les résultats finaux
    fw.visualize()
# Out:
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\njitFunc.py:258: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   fitness[i] = njit_RSS(population[i], data)
# Processing subintervals: 100%|██████████| 90/90 [12:40<00:00,  8.45s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.46result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [10:11<00:00,  6.80s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:15<00:00,  5.95result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [12:15<00:00,  8.17s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:14<00:00,  6.00result/s]

# %% [markdown]
# #### Visualise previous results

# %%
# # On peut aussi load des résultats déjà calculés

# # Pas nécessaire de créer une nouvelle instance de Framework
# fw = Framework("daily")

# # On peut mettre show=True pour afficher les résultats
# fw.analyze("results/MPGA/results-2003_2008_try.json", show=True)

# # Permet d'afficher les résultats finaux
# fw.visualize()

# %% [markdown]
# # SA

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = SA()
fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(fw.results, "results/results-2003_2008_try_SA.json")
# On check la significativité des résultats
fw.analyze()
# On peut visualiser les résultats finaux
fw.visualize()
# Out:
# Processing subintervals: 100%|██████████| 90/90 [00:13<00:00,  6.60subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:15<00:00,  5.82result/s]

# %%
fw = Framework("daily")
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

# Optimiseur à utiliser (SA)
optimizer = SA()  

# Boucle pour exécuter le processus pour chaque set de dates
for set_name, (start_date, end_date) in dates_sets.items():
    print(f"Running process for {set_name} from {start_date} to {end_date}")
    fw.process(start_date, end_date, optimizer)
    # On peut save en json nos résultats pour les réutiliser plus tard
    start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
    end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
    filename = f"results/SA/results-{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}.json"
    # Sauvegarder les résultats
    fw.save_results(fw.results, filename)
    # On check la sig   nificativité des résultats
    fw.analyze()
    # On peut visualiser les résultats finaux
    fw.visualize()
# Out:
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:16<00:00,  5.52subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:18<00:00,  4.90result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:12<00:00,  7.00subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.50result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:12<00:00,  7.00subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:15<00:00,  5.73result/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 24
#      22 fw.analyze()
#      23 # On peut visualiser les résultats finaux
# ---> 24 fw.visualize()
#
# File c:\Users\bapdu\COMMUN\Dauphine\Predicting-Oil-Price-Turning-Points\GQLib\Framework.py:287, in Framework.visualize(self)
#     284 plt.axvline(x=self.global_dates[int(max_time)], color="gray", linestyle="--", label="End Date")
#     286 for tc in significant_tc:
# --> 287     plt.axvline(x=self.global_dates[int(round(tc))], color="red", linestyle=":")
#     289 plt.xlabel("Date")
#     290 plt.ylabel("Price")
#
# IndexError: index 9917 is out of bounds for axis 0 with size 9806

# %% [markdown]
# ## SGA

# %%
fw = Framework("daily")
# On renseigne les dates du sample et l'optimiseur à utiliser
optimizer = SGA()
fw.process("04/01/2003", "04/02/2008", optimizer)
# On peut save en json nos résultats pour les réutiliser plus tard
fw.save_results(fw.results, "results/results-2003_2008_try_SGA.json")
# On check la significativité des résultats
fw.analyze()
# On peut visualiser les résultats finaux
fw.visualize()
# Out:
# Processing subintervals: 100%|██████████| 90/90 [00:53<00:00,  1.67subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:16<00:00,  5.31result/s]

# %%
fw = Framework("daily")
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

# Optimiseur à utiliser (SA)
optimizer = SGA()  

# Boucle pour exécuter le processus pour chaque set de dates
for set_name, (start_date, end_date) in dates_sets.items():
    print(f"Running process for {set_name} from {start_date} to {end_date}")
    fw.process(start_date, end_date, optimizer)
    # On peut save en json nos résultats pour les réutiliser plus tard
    start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
    end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
    filename = f"results/SGA/results-{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}.json"
    # Sauvegarder les résultats
    fw.save_results(fw.results, filename)
    # On check la sig   nificativité des résultats
    fw.analyze()
    # On peut visualiser les résultats finaux
    fw.visualize()
# Out:
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [01:06<00:00,  1.35subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:17<00:00,  5.18result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [01:05<00:00,  1.38subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:20<00:00,  4.46result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [01:17<00:00,  1.16subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:18<00:00,  4.74result/s]
