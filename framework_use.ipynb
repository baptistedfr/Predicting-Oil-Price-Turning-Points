# %%
from GQLib.Framework import Framework
from GQLib.Optimizers import MPGA, PSO, SA, SGA
from datetime import datetime

# %% [markdown]
# ## Run full process for all Optimizers and all dates

# %%
fw = Framework("daily")
optimizers = [MPGA, PSO, SA, SGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running process for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running process for {set_name} from {start_date} to {end_date}")
        fw.process(start_date, end_date, optimizer)
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/PSO/results-{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"
        # Sauvegarder les résultats
        fw.save_results(fw.results, filename)
        # On check la sig   nificativité des résultats
        fw.analyze()
        # On peut visualiser les résultats finaux
        fw.visualize()
# Out:
# Running process for MPGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals:   0%|          | 0/90 [00:00<?, ?subinterval/s]/Users/julesmourgues/Documents/Cours/Master Dauphine/Paper GQ/Predicting-Oil-Price-Turning-Points/GQLib/njitFunc.py:258: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   fitness[i] = njit_RSS(population[i], data)
# Processing subintervals: 100%|██████████| 90/90 [05:01<00:00,  3.35s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.13result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [03:39<00:00,  2.44s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 32.12result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [04:04<00:00,  2.72s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.18result/s]
# Running process for PSO
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [01:31<00:00,  1.02s/subinterval]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.20result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [01:19<00:00,  1.13subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 32.12result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [01:25<00:00,  1.05subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.55result/s]
# Running process for SA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:04<00:00, 20.90subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.10result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:03<00:00, 25.42subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.43result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:03<00:00, 24.10subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.58result/s]
# Running process for SGA
#
# Running process for Set 1 from 01/04/2003 to 02/01/2008
# Processing subintervals: 100%|██████████| 90/90 [00:22<00:00,  4.07subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.71result/s]
# Running process for Set 2 from 01/02/2007 to 01/02/2011
# Processing subintervals: 100%|██████████| 90/90 [00:17<00:00,  5.09subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.38result/s]
# Running process for Set 3 from 29/04/2011 to 01/08/2015
# Processing subintervals: 100%|██████████| 90/90 [00:18<00:00,  4.88subinterval/s]
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.64result/s]

# %% [markdown]
# ## Run analysis for all Optimizers and all dates

# %%
fw = Framework("daily")
optimizers = [MPGA, PSO, SA, SGA]
dates_sets = {
    "Set 1": ("01/04/2003", "02/01/2008"),
    "Set 2": ("01/02/2007", "01/02/2011"),
    "Set 3": ("29/04/2011", "01/08/2015"),
}

for optimizer in optimizers:
    print(f"Running analysis for {optimizer.__name__}\n")
    for set_name, (start_date, end_date) in dates_sets.items():
        print(f"Running analysis for {set_name} from {start_date} to {end_date}")
        # On peut save en json nos résultats pour les réutiliser plus tard
        start_date_obj = datetime.strptime(start_date, "%d/%m/%Y")
        end_date_obj = datetime.strptime(end_date, "%d/%m/%Y")
        filename = f"results/PSO/results-{start_date_obj.strftime('%d-%m-%y')} {end_date_obj.strftime('%d-%m-%y')}_{optimizer.__name__}.json"

        # On check la sig   nificativité des résultats
        fw.analyze(filename, show=True)
        # On peut visualiser les résultats finaux
        fw.visualize()
# Out:
# Running analysis for MPGA
#
# Running analysis for Set 1 from 01/04/2003 to 02/01/2008
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.45result/s]
# Running analysis for Set 2 from 01/02/2007 to 01/02/2011
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.16result/s]
# Running analysis for Set 3 from 29/04/2011 to 01/08/2015
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.59result/s]
# Running analysis for PSO
#
# Running analysis for Set 1 from 01/04/2003 to 02/01/2008
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 27.06result/s]
# Running analysis for Set 2 from 01/02/2007 to 01/02/2011
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.65result/s]
# Running analysis for Set 3 from 29/04/2011 to 01/08/2015
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.55result/s]
# Running analysis for SA
#
# Running analysis for Set 1 from 01/04/2003 to 02/01/2008
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 29.77result/s]
# Running analysis for Set 2 from 01/02/2007 to 01/02/2011
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 32.15result/s]
# Running analysis for Set 3 from 29/04/2011 to 01/08/2015
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.66result/s]
# Running analysis for SGA
#
# Running analysis for Set 1 from 01/04/2003 to 02/01/2008
# Analyzing results: 100%|██████████| 90/90 [00:03<00:00, 28.38result/s]
# Running analysis for Set 2 from 01/02/2007 to 01/02/2011
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 31.58result/s]
# Running analysis for Set 3 from 29/04/2011 to 01/08/2015
# Analyzing results: 100%|██████████| 90/90 [00:02<00:00, 30.96result/s]
